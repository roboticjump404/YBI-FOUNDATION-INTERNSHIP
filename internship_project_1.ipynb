# %% [markdown]
# <a href="https://colab.research.google.com/github/roboticjump404/YBI-FOUNDATION-INTERNSHIP/blob/main/internship_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MILEAGE PREDICTION

# %% [markdown]
# OBJECTIVE :
# To predict the mileage of vehicles

# %% [markdown]
# Data Source: "https://github.com/YBI-Foundation/Dataset/raw/main/MPG.csv"

# %%
#import library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import data
Mil=pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/MPG.csv")
Mil.head(25)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0          8         307.0       130.0    3504          12.0
# 1   15.0          8         350.0       165.0    3693          11.5
# 2   18.0          8         318.0       150.0    3436          11.0
# 3   16.0          8         304.0       150.0    3433          12.0
# 4   17.0          8         302.0       140.0    3449          10.5
# 5   15.0          8         429.0       198.0    4341          10.0
# 6   14.0          8         454.0       220.0    4354           9.0
# 7   14.0          8         440.0       215.0    4312           8.5
# 8   14.0          8         455.0       225.0    4425          10.0
# 9   15.0          8         390.0       190.0    3850           8.5
# 10  15.0          8         383.0       170.0    3563          10.0
# 11  14.0          8         340.0       160.0    3609           8.0
# 12  15.0          8         400.0       150.0    3761           9.5
# ...

# %%
Mil.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
#remove missing values
Mil=Mil.dropna()

# %%
#describe data
Mil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %%
Mil.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    392.000000  392.000000
# mean      15.541327   75.979592
# std        2.758864    3.683737
# min        8.000000   70.000000
# 25%       13.775000   73.000000
# 50%       15.500000   76.000000
# 75%       17.025000   79.000000
# max       24.800000   82.000000

# %%
#data visualisation
sns.regplot(x='displacement',y='mpg',data=Mil)
# Out:
# <Axes: xlabel='displacement', ylabel='mpg'>

# %%
#data preprocessing
Mil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %%
Mil.corr()
# Out:
# <ipython-input-9-b43547f778f7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Mil.corr()
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# model_year    0.580541  -0.345647     -0.369855   -0.416361 -0.309120
#
#               acceleration  model_year
# mpg               0.423329    0.580541
# cylinders        -0.504683   -0.345647
# ...

# %%
Mil.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    392.000000  392.000000
# mean      15.541327   75.979592
# std        2.758864    3.683737
# min        8.000000   70.000000
# 25%       13.775000   73.000000
# 50%       15.500000   76.000000
# 75%       17.025000   79.000000
# max       24.800000   82.000000

# %%
#define target variable y and feature x
Mil.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
y=Mil['mpg']
x=Mil[['displacement', 'horsepower', 'weight',
       'acceleration']]

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.8, random_state=2)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((313, 4), (79, 4), (313,), (79,))

# %%
#linear regression model
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
#modeling
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-0.00612293, -0.04918385, -0.00517318, -0.05346948])

# %%
model.intercept_
# Out:
# 46.12304764785653

# %%
#Predict model
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([30.91329437, 28.14825472, 24.16213348, 32.73753751, 29.90772213,
#        29.86455009, 23.49265026, 28.26113288, 19.45963376, 18.43515704,
#        30.19552592, 20.67845895, 30.12626175, 24.09310747, 25.18662053,
#        25.4628754 , 31.3600862 , 17.05776155, 29.35645718, 21.72395579,
#        10.78476003, 27.47593508, 26.41206944,  8.72145253, 25.8372644 ,
#        21.14415942, 25.9774071 , 19.60836293, 11.88133781, 14.00857795,
#        26.04317077, 31.87209162, 10.09317461, 14.89478782, 30.88150061,
#        29.04079537,  9.30050628, 32.98171621, 27.92730268, 27.72820078,
#        29.56913667, 22.33214141, 24.20811606, 13.46769453, 26.31925626,
#        17.94260811, 23.52484789, 23.37564873, 25.84027318, 19.20514377,
#        25.12282572, 26.93936783, 12.34501717, 27.87962414, 26.8330242 ,
#        14.42763806, 28.29842759, 30.16209506, 27.06950035, 24.27687248,
#        15.03632727, 27.64924047,  6.0701545 , 26.92863409, 20.09818608,
# ...

# %%
# model accuracy and evaluation
from sklearn.metrics import mean_absolute_percentage_error as mape
a=mape(y_test,y_pred)
a
#hence model is 87% accurate with 13% of error
# Out:
# 0.13612255106227564

# %%
pred=model.predict([[110.0,	87.0,	2672,	17.5	]])
print(pred)
# Out:
# [26.41206944]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# EXPLANATION

# %%
# 1. Data is imported from the provided URL using pandas' `read_csv()` function and stored in the 'Mil' DataFrame.
# 2. The initial structure of the dataset is explored by displaying the first few rows and checking the column names.
# 3. Rows with missing values are removed using the `dropna()` method to ensure data cleanliness.
# 4. Basic information and statistical summary of the dataset are displayed using `info()` and `describe()` functions.
# 5. The relationship between 'displacement' and 'mpg' is visualized with a regression plot using seaborn's `regplot()`.
# 6. Feature variables are selected as 'x', and the target variable is assigned to 'y'.
# 7. The dataset is split into training and testing subsets using the `train_test_split()` function.
# 8. A linear regression model is created using scikit-learn's `LinearRegression()` class.
# 9. The linear regression model is trained on the training data using the `fit()` method.
# 10. The coefficients and the intercept of the linear regression model are displayed.
# 11. The model is used to predict the target variable  on the test data.
# 12. The Mean Absolute Percentage Error (MAPE) metric is imported from scikit-learn, and the model's accuracy is calculated using it.
# 13. The calculated MAPE is printed to evaluate the model's accuracy.
